# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshitSoni0401/AirBnbProject/blob/main/Individual_work_AirBNB_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - AIRBNB BOOKING ANALYSIS

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -** Harshit Soni
# ##### **Team Member 2 -** Kartikey
# ##### **Team Member 3 -** Tanya
# ##### **Team Member 4 -** Shiv Safar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
#  The goal of this EDA is to extract valuable insights, patterns, and trends from this data. In this summary, we'll discuss key findings and trends uncovered during the analysis.The dataset comprises several columns, including host and property information, geographical coordinates, room type, price, minimum nights, reviews, and more. It offers a comprehensive view of the Airbnb landscape in NYC.Manhattan and Brooklyn have the highest concentrations of listings, while the Bronx and Staten Island have fewer offerings.The price distribution across NYC neighborhoods shows significant variation. Manhattan, particularly the neighborhoods of Manhattan Island, has the highest average prices, reflecting its status as a prime tourist destination. In contrast, Staten Island and the Bronx offer more affordable accommodations.A notable observation is the presence of hosts with a wide range of property listings. Some hosts manage multiple listings, suggesting the presence of property management companies in the NYC Airbnb market.Correlation analysis reveals interesting relationships between variables.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# which room type has more bookings???
#
# Which room type has generated more revenue???
#
# Which neighbourhood has more number of hotels??
#
# Ratings(num of reviews) based in the room types???
#
# What is the distribution of minimum nights required for bookings in different neighborhoods???
#
# Which host has the most diverse range of room types available?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/Airbnb NYC 2019.csv'

# %%
hotel_data = pd.read_csv(file_path)
hotel_data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
hotel_data.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  availability_365  latitude  longitude  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
row_num = hotel_data.shape[0]
column_num = hotel_data.shape[1]
print('number of columns:', column_num)
print('number of rows:', row_num)
# Out:
# number of columns: 16
# number of rows: 48895

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   room_type                       48895 non-null  object
#  7   price                           48895 non-null  int64
#  8   minimum_nights                  48895 non-null  int64
#  9   number_of_reviews               48895 non-null  int64
#  10  availability_365                48895 non-null  int64
#  11  latitude                        48895 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_rows = hotel_data[hotel_data.duplicated()]
num_duplicate_rows = duplicate_rows.shape[0]
num_duplicate_rows
# Out:
# 0

# %%
hotel_data.nunique()
# Out:
# id                                48895
# name                              47896
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# availability_365                    366
# latitude                          19048
# longitude                         14718
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
hotel_data.isnull().any()
# Out:
# id                                False
# name                               True
# host_id                           False
# host_name                          True
# neighbourhood_group               False
# neighbourhood                     False
# room_type                         False
# price                             False
# minimum_nights                    False
# number_of_reviews                 False
# availability_365                  False
# latitude                          False
# longitude                         False
# last_review                        True
# reviews_per_month                  True
# calculated_host_listings_count    False
# dtype: bool

# %%
# Visualizing the missing values
hotel_data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# availability_365                      0
# latitude                              0
# longitude                             0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hotel_data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'availability_365', 'latitude', 'longitude',
#        'last_review', 'reviews_per_month', 'calculated_host_listings_count'],
#       dtype='object')

# %%
# Dataset Describe
hotel_data.describe()
# Out:
#                  id       host_id         price  minimum_nights  \
# count  4.889500e+04  4.889500e+04  48895.000000    48895.000000
# mean   1.901714e+07  6.762001e+07    152.720687        7.029962
# std    1.098311e+07  7.861097e+07    240.154170       20.510550
# min    2.539000e+03  2.438000e+03      0.000000        1.000000
# 25%    9.471945e+06  7.822033e+06     69.000000        1.000000
# 50%    1.967728e+07  3.079382e+07    106.000000        3.000000
# 75%    2.915218e+07  1.074344e+08    175.000000        5.000000
# max    3.648724e+07  2.743213e+08  10000.000000     1250.000000
#
#        number_of_reviews  availability_365      latitude     longitude  \
# count       48895.000000      48895.000000  48895.000000  48895.000000
# mean           23.274466        112.781327     40.728949    -73.952170
# std            44.550582        131.622289      0.054530      0.046157
# min             0.000000          0.000000     40.499790    -74.244420
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
hotel_data.drop(['latitude', 'longitude', 'last_review', 'reviews_per_month'], axis = 1, inplace = True)
hotel_data.drop(['calculated_host_listings_count'],axis=1,inplace = True)

# %%
hotel_data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
sns.boxplot(x = 'price', data = hotel_data)
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
#1 which room type has more bookings???

#2 Which room type has generated more revenue???

#3 Which neighbourhood has more number of hotels??

#4 Ratings(num of reviews) based in the room types???

#### What is the distribution of minimum nights required for bookings in different neighborhoods???

#### Which host has the most diverse range of room types available?

#5  Which neighbourhood group has  more hosts number

#6 Which neighbourhood is more expensive???

#7 To Understand the relation in the dataset

#8 To check the number of room type availabel in the neighbourhood group

#9  To Check the Co-relation between the data

#10  Which room type has more cost and is present in which neighbourhood group

#11 Number of Neighbourhoods in each Neighbourhood Group

# %%
# Chart - 1 visualization code
# Ploting a Bar Chart based on Room_Type by AVG Number of Reviews of it to see
# which room type has more bookings as compared to others

avg_booking = hotel_data.groupby('room_type').agg({'number_of_reviews':'mean'})
avg_booking = avg_booking.reset_index()
plt.figure(figsize=(7, 6))
sns.barplot(x='room_type', y='number_of_reviews', data = avg_booking)

# plt.xlabel('Room Types')
# plt.ylabel('Prices')
# plt.title('Bar Plot of Mean Price by Room Type Column')
# Out:
# <Axes: xlabel='room_type', ylabel='number_of_reviews'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Which room type has generated more revenue???

hotel_data['price'] = hotel_data['price'].astype(int)
hotel_data['number_of_reviews'] = hotel_data['number_of_reviews'].astype(int)

hotel_data['result'] = hotel_data['price'] * hotel_data['number_of_reviews']

avg_booking = hotel_data.groupby('room_type').agg({'result':'mean'})

avg_booking = avg_booking.reset_index()
# avg_booking
sns.barplot(x= 'result',y = 'room_type' , data = hotel_data, orient= 'h')
# Out:
# <Axes: xlabel='result', ylabel='room_type'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Which neighbourhood has more number of hotels??

num_of_hotels_nbhd = hotel_data.groupby('neighbourhood_group').agg({'id':'count'})
num_of_hotels_nbhd = num_of_hotels_nbhd.reset_index()

# sns.barplot(x = num_of_hotels_nbhd.neighbourhood_group, y= num_of_hotels_nbhd.id)
plt.figure(figsize=(6, 6))
plt.pie(num_of_hotels_nbhd['id'], labels=num_of_hotels_nbhd['neighbourhood_group'], autopct='%1.1f%%')


plt.xlabel('Neighbourhood Groups')
plt.ylabel('Number of Hotel')
plt.title('Number of hotels in Neighbourhood')
# Out:
# Text(0.5, 1.0, 'Number of hotels in Neighbourhood')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Ratings(num of reviews) based in the room types???
sum_of_reviews = hotel_data.groupby('room_type').agg({'number_of_reviews':'sum'})
sum_of_reviews = sum_of_reviews.reset_index()
# sum_of_reviews
sns.barplot(x = 'room_type', y = 'number_of_reviews', data = sum_of_reviews)
# Out:
# <Axes: xlabel='room_type', ylabel='number_of_reviews'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#  Which neighbourhood group has  more hosts number
num_hosts_nbhd = hotel_data.groupby('neighbourhood_group').agg({'host_name':'count'})
num_hosts_nbhd = avg_booking.reset_index()
num_hosts_nbhd
# sns.barplot(x = num_hosts_nbhd['neighbourhood_group'], y = num_hosts_nbhd['host_name'] )
sns.barplot(data=num_hosts_nbhd, x = 'room_type', y= 'result')
# Out:
# <Axes: xlabel='room_type', ylabel='result'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Which neighbourhood is more expensive???

agg_data = hotel_data.groupby('neighbourhood_group')['price'].sum().reset_index()

sns.barplot(data = agg_data, x = 'neighbourhood_group', y= 'price')

plt.xlabel('Neighbourhood Groups')
plt.ylabel('Price')
plt.title('Expensiveness by Neighbourhood Groups')
# Out:
# Text(0.5, 1.0, 'Expensiveness by Neighbourhood Groups')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# To Understand the relation in the dataset
sns.pairplot(hotel_data,dropna = True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# To check the number of room type availabel in the neighbourhood group
sns.countplot(data=hotel_data, x='neighbourhood_group', hue = 'room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
#  To Check the Co-relation between the data
sns.heatmap(data = hotel_data.corr(),annot=True, cmap= 'coolwarm')
# Out:
# <ipython-input-29-ba20c23d22c6>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data = hotel_data.corr(),annot=True, cmap= 'coolwarm')
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#  Which room type has more cost and is present in which neighbourhood group
sns.scatterplot(data = hotel_data, x = 'neighbourhood_group', y= 'price',hue= 'room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Number of Neighbourhoods in each Neighbourhood Group
cnt_nhbd = hotel_data.groupby('neighbourhood_group')['neighbourhood'].count().reset_index()
cnt_nhbd
sns.barplot(data = cnt_nhbd, x = 'neighbourhood_group', y='neighbourhood')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='neighbourhood'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
